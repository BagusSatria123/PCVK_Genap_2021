# %% [markdown]
# <a href="https://colab.research.google.com/github/BagusSatria123/PCVK_Genap_2021/blob/master/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# Accessing My Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/pcvk/img/kitten-run.jpg')
plt.imshow(img) # perhatikan hasilnya adalah citra dengan channel warna BGR

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB) # konversi channel BGR -> RGB
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/pcvk/img/kitten-run.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

# simpan file image
# cv.imwrite('/content/drive/MyDrive/pcvk/img/mandrill2.tiff',img5)

# tampilkan plot dengan ukuran canvas yang lebih besar
fig = plt.figure(figsize=(10,10)) # ubah-ubah ukuran (10,10) sesuai kebutuhan
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
# perhatikan koordinat titik" pt1 dan pt2
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2 = np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],
                     [200,200],
                     [400,300],
                     [200,400]], dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2))
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# **Tugas 1**

# %%
#nomor 2
# Red-Green
img_rg = img.copy()
img_rg[:,:,2] = 0
plt.imshow(img_rg)

# %%
#nomor 2
# Green-Blue
img_gb = img
img_gb[:,:,0] = 0
plt.imshow(img_gb)

# %%
#nomor 1
img_t = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

fig = plt.figure(figsize=(7,7))
ax = fig.add_subplot(111)
ax.imshow(img_t)

# %%
#nomor 3
img_k = img[20:250,20:250]
plt.imshow(img_k)

# %%
#nomor 4
plt.imshow(img[7:27])

# %%
#nomor 5
img_ktk = cv.cvtColor(img,cv.COLOR_BGR2RGB)
cv.rectangle(img_ktk, pt1=(300,300), pt2=(40,170), color=(0,255,255), thickness=10)
cv.rectangle(img_ktk, pt1=(100,900), pt2=(300,400), color=(255,0,0),thickness=10)
cv.rectangle(img_ktk, pt1=(200,300), pt2=(600,400), color=(0,0,255),thickness=10)
plt.imshow(img_ktk)

# %% [markdown]
# **Tugas 2**

# %%
#nomor 1
img_f = cv.imread('/content/drive/MyDrive/pcvk/img/my-photo.jpg')
plt.imshow(img_f)

# %%
#nomor 1 lanjutan
img233 = img_f
img333 = cv.cvtColor(img_f,cv.COLOR_BGR2RGB) # konversi channel BGR -> RGB
plt.imshow(img333)

# %%
#nomor 1 lanjutan
cv.rectangle(img333,pt1=(350,60),pt2=(100,350),color=(0,0,255),thickness=15)
plt.imshow(img333)

# %%
#nomor 1 lanjutan
cv.circle(img333,center=(225,200),radius=120,color=(255,0,0),thickness=8)
plt.imshow(img333)

# %%
#nomor 2
img_b = cv.imread('/content/drive/MyDrive/pcvk/img/peppers.tiff')
plt.imshow(img_b)

# %%
#nomor 2
img_rgb = cv.cvtColor(img_b,cv.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %%
#nomor 2
cv.rectangle(img_rgb,pt1=(50,165),pt2=(10,200),color=(0,255,0),thickness=10)
plt.imshow(img_rgb)

# %%
#nomor 3
font = cv.FONT_HERSHEY_SCRIPT_COMPLEX
cv.putText(img_rgb,text='Ini buah Paprika',org=(10,100),fontFace=font,fontScale=0.8,color=(0,255,255),thickness=2,lineType=cv.LINE_AA)
plt.imshow(img_rgb)

# %% [markdown]
# **Pertanyaan**

# %% [markdown]
# 1. Apakah perbedaan gambar yang ditampilkan tanpa dan dengan matplotlib?
#
#
#
#    Menggunakan matplotlib sebuah gambar grafik yang terdapat satu sumbuh atau lebih.Setiap sumbuh     memiliki  sumbu horizontal (x) dan sumbu vertikal (y), dan data yang direpresentasikan menjadi warna dan glyphs seperti marker (contohnya bentuk lingkaran) atau lines (garis) atau poligon.
#    sedangkan tanpa matplotlib sulit memvisualisasikan data secara 2D maupun 3D di dalam Python dan menghasilkan gambar berkualitas dalam berbagai format.

# %% [markdown]
# 2. Apakah perbedaan dan pengaruhnya pembuatan black image antara tipe data int16
# dan int32?
#
#     Int16: 2 byte
#
#     Int32 dan int: 4 byte
#
#     Int64 : 8 byte
#
# Ada satu perbedaan kecil antara Int64 dan sisanya. Pada 32 bit platform tugas ke sebuah Int64 lokasi penyimpanan tidak dijamin untuk menjadi atom. Hal ini dijamin untuk semua jenis lain.

# %% [markdown]
# 3. Apakah kegunaan “google.colab.patches import cv2_imshow” pada potongan kode
# berikut
#
# mengambil / import gambar dari drive kita yang telah disimpan

# %% [markdown]
# 4. Apakah kegunaan “skimage import io” pada potongan kode soal nomor 3
#
# Python Digital Image Processing yang akan muncul gambar berupa blue,red,green bukan RGB
